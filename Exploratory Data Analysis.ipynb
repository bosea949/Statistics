# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1 . Explain the difference between hypothesis testing and exploratory data
# analysis?

# %% [markdown]
# Answer :
#     Testing of Hypothesis:
#                        In a hypothesis-driven analysis one must be very specific about the analysis one wishes to perform.The null hypothesis must be clearly stated, and the data must be collected in a repeatable manner. Usually, the sampling design will involve random, stratified random, or regular distribution of study plots. If there is any subjectivity involved in locating or orienting study plots, the results are technically not valid. All of the analyses, including variations of data transformation and use of different ordination options (e.g. detrending or not), must be planned in advance, or else the user runs the risk of "data diving" or "data mining", i.e. getting an artificially significant result because so many options are tried. Stepwise techniques are automated forms of "data diving", and will typically also lead to incorrect statistical inference. The reward for rigorously adhering to these rather stringent criteria is that the statistical inference is valid.

# %% [markdown]
#  Exploratory Data Analysis:
#                                The purpose of exploratory analysis is to find pattern in nature, which is an inherently subjective enterprise. Exploratory analyses incorporate the wisdom, skill, and intuition of the investigator into the experiment. Unless one can find another investigator with identical wisdom, skill and intuition, the analyses are not strictly repeatable, and are hence not falsifiable. An exploratory analysis can be aided if the investigator subjectively places study plots in locations he or she considers to be important or interesting. Orienting plots within vegetation which appears homogeneous is highly subjective, but very useful in evaluating differences between plots.
# With exploratory analysis, "data diving" (e.g. using different transformations of species abundances, adjusting ordination options, selecting different subsets of environmental variables, or selecting different subsets of study plots) is no longer to be avoided. Instead, it is a way for the investigator to learn more about the data set. Stepwise analysis is a form of automated data diving. It is useful as a tool to help discover "important" or "interesting" variables.

# %% [markdown]
# 2 . The goal of exploratory data analysis is to build analytical models. Is this
# a true statement? Why or why not?

# %% [markdown]
# Answer : Not exactly. The goal of exploratory data analysis is to extract information from the data and understand the structure of the data, which is a prequisite for modeling.

# %% [markdown]
# 3 . Missing data for any attribute must always be addressed by some suitable
# technique regardless of how much data you have, for example, replacing by
# the mean for numerical attributes and the mode for categorical attributes.
# Is this a true statement? Why or why not?

# %% [markdown]
# Answer : If the data is too large then it need not be neccessary to apply suitable techniques to deal with missing values. But in case the data is not really large, droping rows may incur bias in the analysis of the data. For these cases it becomes neccessary to apply techniques such imputation in presence of missing values.

# %% [markdown]
# 4 . List the type associated with each of the attributes and the summary
# statistics associated with each of the attributes in the adult dataset.

# %%
df=pd.read_csv("Adult Dataset.csv")

# %%
df
# Out:
#        Age          Workclass  Fnlwgt      Education  Education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education-num  Capital-gain  Capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education-num      int64
# Martial-status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital-gain       int64
# Capital-loss       int64
# Hours-per-week     int64
# Native-country    object
# Income            object
# dtype: object

# %% [markdown]
# 5 . How can we examine correlation between numerical variables? Identifying
# correlation can be important for certain statistical models? Which ones
# and how do they affect these models?

# %% [markdown]
# Answer :We analyse graphical display, that is , scatterplot to have a an idea about correlations. Mathematically, correlation is given by the formula: cov(x,y)/(sd(x)*sd(y)). We also conduct statistical test for correlation. Here we take the null hypotheisis as zero correlation and the alternative as the otherwise.Here the test statistics is taken as T=r*((n-1/1-r^2)^1/2) which has a t-distribution with n-1 degrees of freedom under the null hypothesis.

# %% [markdown]
# Specially in multiple regression models, correlation play an important role. Presence of significant correlation among the predictor variables in a multiple regression model can have consequence such as multicollinearity. Multicollinearity does not reduce the prediction power or reliability of the model but results may not valid for individual prediction due toredundancy. Coefficient of estimates may change in response to small changes in the modelor data. In the presence of multicollinearity, the estimate of one variable's impact on the dependent variable y while controlling for the others tends to be less precise than if predictors were uncorrelated with one another.

# %% [markdown]
# If the variables are accorded different names and perhaps employ different numeric measurement scales but are highly correlated with each other, then they suffer from redundancy. One of the features of multicollinearity is that the standard errors of the affected coefficients tend to be large. In that case, the test of the hypothesis that the coefficient is equal to Zero may lead to a failure to reflect a false null hypothesis of no effect of the explanator, a type of error  (fail to reflect the wrong decision).

# %% [markdown]
# 6 . Why bother with exploratory data analysis, we might as well go ahead
# and perform the end goal of building some model. Explain why this is a
# bad idea.

# %% [markdown]
# Answer : Exploratory data analysis is important before building some model because of the following reasons:

# %% [markdown]
#  * It aids in detecting Incomplete data.

# %% [markdown]
#  * Removing abnormality in the data such as outliers, noise such as missing values, abnormal observations,etc.

# %% [markdown]
#  * Remove columns with too much correlation, that is reduce redundant variables.

# %% [markdown]
#  * Find new features of the data.

# %% [markdown]
#  * It also helps in better approximation of the model.

# %% [markdown]
# 7 . How would you test if two categorical variables are independent? What
# statistical test is used to perform this?

# %% [markdown]
# Answer : Two catagorical variables are tested using the chi-square test of independence.
#
#  The test consists of four steps: (1) state the hypotheses, (2) formulate an analysis plan, (3) analyze sample data, and (4) interpret results.
#
#     State the hypotheses:- A chi-square test for independence is conducted on two categorical variables. Suppose that Variable A has r levels, and Variable B has c levels. The null hypothesis states that knowing the level of        Variable A does not help you predict the level of Variable B. That is, the variables are independent. The         alternative  hypothesis states that the variables are not independent.
#
#     Formulate analysis plan:- The analysis plan describes how to use sample data to accept or reject the null          hypothesis. The plan should specify a significance level and should identify the chi-square test for independence as the test method.
#
#     Analyze sample data. Using sample data, find the degrees of freedom, expected frequencies, test statistic, and    the P-value associated with the test statistic.
#
#         Degrees of freedom. The degrees of freedom (DF) is equal to:
#
#         DF = (r - 1) * (c - 1)
#         where r is the number of levels for one catagorical variable, and c is the number of levels for the other             categorical variable.
#
#         Expected frequencies:- The expected frequency counts are computed separately for each level of one              categorical variable at each level of the other categorical variable. Compute r*c expected frequencies, according to the following formula.
#
#         Er,c = (nr * nc) / n
#         where Er,c is the expected frequency count for level r of Variable A and level c of Variable B, nr is the     total number of sample observations at level r of Variable A, nc is the total number of sample observations at      level c of Variable B, and n is the total sample size.
#
#         Test statistic:- The test statistic is a chi-square random variable (Χ2) defined by the following equation:
#
#         Χ2 = Σ [ (Or,c - Er,c)^2 / Er,c ]
#         where Or,c is the observed frequency count at level r of Variable A and level c of Variable B, and Er,c is     the expected frequency count at level r of Variable A and level c of Variable B.
#
#         P-value:- The P-value is the probability of observing a sample statistic as extreme as the test statistic.    Since the test statistic is a chi-square, use the Chi-Square Distribution Calculator to assess the probability       associated with the test statistic. Use the degrees of freedom computed above.
#
#     Interpret results:-  If the sample findings are unlikely, given the null hypothesis, the researcher rejects the    null hypothesis. Typically, this involves comparing the P-value to the significance level , and rejecting the        null  hypothesis when the P-value is less than the significance level.

# %% [markdown]
# 8 . What are some tools we could use to determine documentation about the
# attributes in the dataset and how the data was generated?

# %% [markdown]
# Answer :
#         The tool that stores information about the data is called Metadata. It is data that provides information about other data.
# Metadata can be of different types:
#
# * Descriptive metadata describes a resource for purposes such as discovery and identification. It can include elements such as title, abstract, author, and keywords.
# * Structural metadata is metadata about containers of data and indicates how compound objects are put together, for example, how pages are ordered to form chapters. It describes the types, versions, relationships and other characteristics of digital materials.
# * Administrative metadata provides information to help manage a resource, such as when and how it was created, file type and other technical information, and who can access it.
# * Reference metadata describes the contents and quality of statistical data
# * Statistical metadata may also describe processes that collect, process, or produce statistical data; such metadata are also called process data.

# %% [markdown]
# 9 . Discretize the age and the education-num attributes. How do we decide
# the number of bins? Use a the Freedman-Diaconis rule to determine the
# number of bins.

# %% [markdown]
# Answer : Here we use the Freedman-Diaconis rule to determine the bin widths of the histograms. The Freedman-Diaconis rule states that an appropriate bin width of a histogram is given by:

# %% [markdown]
# bin_width= 2*IQR/pow(n,1/3)
# where IQR is the inter-quartile range of the data and n is the total number of observations in the table.

# %%
age=df[["Age"]]
summary=age.describe()
summary
# Out:
#                 Age
# count  32561.000000
# mean      38.581647
# std       13.640433
# min       17.000000
# 25%       28.000000
# 50%       37.000000
# 75%       48.000000
# max       90.000000

# %%
bin_width=2*(summary["Age"]["75%"]-summary["Age"]["25%"])/pow(summary["Age"]["count"],1/3)#Freedman-Diaconis rule
bin_width
# Out:
# 1.2526432809331143

# %%
plt.hist(age["Age"],density=True,rwidth=bin_width)
plt.title("Age histogram")
plt.xlabel("Age")
plt.ylabel("Frequency Density")
# Out:
# Text(0,0.5,'Frequency Density')

# %%
education_num=df[["Education-num"]]

# %%
summary=education_num.describe()                   
summary
# Out:
#        Education-num
# count   32561.000000
# mean       10.080679
# std         2.572720
# min         1.000000
# 25%         9.000000
# 50%        10.000000
# 75%        12.000000
# max        16.000000

# %%
bin_width=2*(summary["Education-num"]["75%"]-summary["Education-num"]["25%"])/pow(summary["Education-num"]["count"],1/3)#Freedman-Diaconis rule
bin_width
# Out:
# 0.18789649213996712

# %%
plt.hist(education_num["Education-num"],density=True,rwidth=bin_width)
plt.title("Education-num histogram")
plt.xlabel("Education-num")
plt.ylabel("Frequency Density")
# Out:
# Text(0,0.5,'Frequency Density')

# %% [markdown]
# 10 . Provide the age histogram of the people who earn more than 50 K

# %% [markdown]
# Answer :

# %%
age_earn=df[["Age","Income"]]
age_earnabove50=age_earn.loc[age_earn["Income"]==" >50K"]

# %%
age_earnabove50.head()
# Out:
#     Age Income
# 7    52   >50K
# 8    31   >50K
# 9    42   >50K
# 10   37   >50K
# 11   30   >50K

# %%
summary=age_earnabove50.describe()

# %%
summary
# Out:
#                Age
# count  7841.000000
# mean     44.249841
# std      10.519028
# min      19.000000
# 25%      36.000000
# 50%      44.000000
# 75%      51.000000
# max      90.000000

# %%
bin_width=2*(summary["Age"]["75%"]-summary["Age"]["25%"])/pow(summary["Age"]["count"],1/3)#Freedman-Diaconis rule
bin_width
# Out:
# 1.5100712416056383

# %%
plt.hist(age_earnabove50["Age"],density=True,rwidth=bin_width)
plt.title("Age histogram for those having income above 50K")
plt.xlabel("Age")
plt.ylabel("Frequency Density")
# Out:
# Text(0,0.5,'Frequency Density')

# %% [markdown]
# 11 . Determine the proportion of males and females in the group that earns
# more than 50 K.

# %% [markdown]
# Answer :

# %%
sex_earn=df[["Sex","Income"]]
sex_earnabove50=sex_earn.loc[sex_earn["Income"]==" >50K"]

# %%
sex_earnabove50.head()
# Out:
#         Sex Income
# 7      Male   >50K
# 8    Female   >50K
# 9      Male   >50K
# 10     Male   >50K
# 11     Male   >50K

# %%
sex_split=sex_earnabove50.groupby("Sex").count().reset_index()
sex_split = sex_split[['Sex', 'Income']].rename(columns={'Sex' : 'Sex', 'Income' : 'Frequency'})
sex_split
# Out:
#        Sex  Frequency
# 0   Female       1179
# 1     Male       6662

# %%
total=sum(sex_split["Frequency"])

# %%
x=sex_split["Frequency"][0]/total
y=sex_split["Frequency"][1]/total

# %%
print("The proportion of males and females who earn more than 50K are %.5f"%x," and %.5f"%y," respectively.")
# Out:
# The proportion of males and females who earn more than 50K are 0.15036  and 0.84964  respectively.

# %% [markdown]
# 12 . Investigate if gender and income are independent? Use the chi-square test
# of independence.

# %% [markdown]
# Answer:

# %%
gender_income=df[["Sex","Income"]]

# %%
tab = pd.crosstab(gender_income.Sex, gender_income.Income)
tab
# Out:
# Income    <=50K   >50K
# Sex
#  Female    9592   1179
#  Male     15128   6662

# %%
from scipy.stats import chi2_contingency
chi_value,p_value,_,_=chi2_contingency(tab)
print("chi-square value is",chi_value)
print("Let us take the size of test as 0.05")
alpha=0.05
print("Here the null hypothesis is that gender and income are not independent and the alternative hypotheisis is otherwise.")
print("p-value of the test %.10f"%p_value)
if p_value<=alpha:
    print("Here we reject the null hypothesis and conclude at 5% level of significance that gender and income are independent.")
else:
    print("Here we conclude at 5% level of significance in favour of the null hypothesis that gender and income are not independent.")
# Out:
# chi-square value is 1517.813409134445
# Let us take the size of test as 0.05
# Here the null hypothesis is that gender and income are not independent and the alternative hypotheisis is otherwise.
# p-value of the test 0.0000000000
# Here we reject the null hypothesis and conclude at 5% level of significance that gender and income are independent.

# %% [markdown]
# 13 . Subset the numerical variables of your dataset into a separate dataframe.
# Plot the scatter matrix for each pair of variables.

# %% [markdown]
# Answer :

# %%
num_attributes=[]
for i in list(df):
    if df[i].dtype=='int64':
        num_attributes.append(i)
num_data=df[num_attributes]

# %%
num_data.head()
# Out:
#    Age  Fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40

# %%
import seaborn as sns
plot=sns.pairplot(num_data)
plot

# %% [markdown]
# 14. Some examples of attribute noise include:
# • Unknown or missing values
# • Incorrect values (values that violate the range of values possible for
# the attribute)
# Does this dataset have noisy attributes? Provide your assessment of how
# many attributes have this problem.

# %% [markdown]
# Answer : Yes, the dataset do have noise in the form of missing values.

# %%
l=list(df)
count=0
for i in l:
    if df[i].isin([" ?"]).values.any():
        count+=1
print("The number of attributes having noise in the form of missing values is",count,".")
# Out:
# The number of attributes having noise in the form of missing values is 3 .

# %% [markdown]
# 15 . What is the Interquartile-Range for an attribute? How can it be used for
# determining outliers for an attribute? Generate box-plots for the continuous
# attributes.

# %% [markdown]
# Answer : Interquartile for an attribute is defined as the difference between the 3rd and the 1st quartile.
# It is taken as threshold in the sense that if any data point lies outside this range is to be marked as an outlier.

# %%
continuous=df[num_attributes]

# %%
for i in num_attributes:
    plt.figure()
    plt.figure().suptitle("Boxplot of "+i, fontsize=10)    
    plt.boxplot(continuous[i])
    plt.show()

# %% [markdown]
# Comment: From the boxplots above, apart from the boxplot of Education-num the boxplots of all other continuous variables display significant presence of outliers incur noise in the data. An addition to the answer of question 14.
